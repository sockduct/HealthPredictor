# %% [markdown]
# # Analyze HealthPredictor Notebook Runs

# %%
# Standard Library:
from collections import defaultdict
import shelve

# 3rd Party:
from IPython.display import display as display
import pandas as pd

# Shelve Database:
DB = 'hp_results'

# %%
# Load the shelve database
with shelve.open(DB) as db:
    # Create a dictionary to group runs by model
    model_data = defaultdict(dict)

    for full_key, metrics in db.items():
        # Split into run and model
        run, model = full_key.split('/', 1)
        model_data[model][run] = metrics

# Now convert each model's runs into a DataFrame
model_dfs = {}

for model, runs in model_data.items():
    df = pd.DataFrame.from_dict(runs, orient='index')
    df.index.name = 'RUN#'
    model_dfs[model] = df

# Now model_dfs is a dictionary: model name -> corresponding DataFrame
for model in model_dfs:
    print(f'{model} model runs:\n{'=' * 100}')
    display(model_dfs[model])
    print(f'{model} model run statistics:\n{'=' * 100}')
    display(model_dfs[model].describe())
# Out:
# DecisionTreeClassifier model runs:
# ====================================================================================================
#       true_positive  true_negative  false_negative  false_postive  accuracy  \
# RUN#
# 0                71             42               1              6  0.941667
# 1                70             46               2              2  0.966667
# 2                70             48               2              0  0.983333
# 3                72             44               0              4  0.966667
# 4                68             43               4              5  0.925000
# ...             ...            ...             ...            ...       ...
# 95               71             45               1              3  0.966667
# 96               71             45               1              3  0.966667
# 97               70             43               2              5  0.941667
# 98               72             43               0              5  0.958333
# 99               72             45               0              3  0.975000
#
#       precision    recall  f1_score  misclassification       npv       fpr  \
# RUN#
# 0      0.922078  0.986111  0.953020           0.058333  0.976744  0.125000
# 1      0.972222  0.972222  0.972222           0.033333  0.958333  0.041667
# 2      1.000000  0.972222  0.985915           0.016667  0.960000  0.000000
# 3      0.947368  1.000000  0.972973           0.033333  1.000000  0.083333
# 4      0.931507  0.944444  0.937931           0.075000  0.914894  0.104167
# ...         ...       ...       ...                ...       ...       ...
# 95     0.959459  0.986111  0.972603           0.033333  0.978261  0.062500
# 96     0.959459  0.986111  0.972603           0.033333  0.978261  0.062500
# 97     0.933333  0.972222  0.952381           0.058333  0.955556  0.104167
# 98     0.935065  1.000000  0.966443           0.041667  1.000000  0.104167
# 99     0.960000  1.000000  0.979592           0.025000  1.000000  0.062500
#
#       specificity  prevalence imputation
# RUN#
# 0        0.875000         0.6     random
# 1        0.958333         0.6     random
# 2        1.000000         0.6     random
# 3        0.916667         0.6     random
# 4        0.895833         0.6     random
# ...           ...         ...        ...
# 95       0.937500         0.6     random
# 96       0.937500         0.6     random
# 97       0.895833         0.6     random
# 98       0.895833         0.6     random
# 99       0.937500         0.6     random
#
# [100 rows x 14 columns]
# DecisionTreeClassifier model run statistics:
# ====================================================================================================
#        true_positive  true_negative  false_negative  false_postive  \
# count     100.000000     100.000000      100.000000     100.000000
# mean       70.460000      44.140000        1.540000       3.860000
# std         1.395664       1.563601        1.395664       1.563601
# min        67.000000      40.000000        0.000000       0.000000
# 25%        70.000000      43.000000        0.000000       3.000000
# 50%        71.000000      44.000000        1.000000       4.000000
# 75%        72.000000      45.000000        2.000000       5.000000
# max        72.000000      48.000000        5.000000       8.000000
#
#          accuracy   precision      recall    f1_score  misclassification  \
# count  100.000000  100.000000  100.000000  100.000000         100.000000
# mean     0.955000    0.948570    0.978611    0.963107           0.045000
# std      0.014361    0.019549    0.019384    0.011772           0.014361
# min      0.916667    0.900000    0.930556    0.931507           0.016667
# 25%      0.941667    0.934211    0.972222    0.953020           0.033333
# 50%      0.958333    0.947368    0.986111    0.965035           0.041667
# 75%      0.966667    0.959459    1.000000    0.972603           0.058333
# max      0.983333    1.000000    1.000000    0.986301           0.083333
#
#               npv         fpr  specificity  prevalence
# count  100.000000  100.000000   100.000000       100.0
# mean     0.967451    0.080417     0.919583         0.6
# std      0.028723    0.032575     0.032575         0.0
# min      0.900000    0.000000     0.833333         0.6
# 25%      0.955303    0.062500     0.895833         0.6
# 50%      0.977008    0.083333     0.916667         0.6
# 75%      1.000000    0.104167     0.937500         0.6
# max      1.000000    0.166667     1.000000         0.6
# DecisionTreeClassifier-GridSearchCV model runs:
# ====================================================================================================
#       true_positive  true_negative  false_negative  false_postive  accuracy  \
# RUN#
# 0                72             44               0              4  0.966667
# 1                71             45               1              3  0.966667
# 2                72             47               0              1  0.991667
# 3                69             44               3              4  0.941667
# 4                72             39               0              9  0.925000
# ...             ...            ...             ...            ...       ...
# 95               67             47               5              1  0.950000
# 96               72             45               0              3  0.975000
# 97               70             44               2              4  0.950000
# 98               72             42               0              6  0.950000
# 99               71             44               1              4  0.958333
#
#       precision    recall  f1_score  misclassification       npv       fpr  \
# RUN#
# 0      0.947368  1.000000  0.972973           0.033333  1.000000  0.083333
# 1      0.959459  0.986111  0.972603           0.033333  0.978261  0.062500
# 2      0.986301  1.000000  0.993103           0.008333  1.000000  0.020833
# 3      0.945205  0.958333  0.951724           0.058333  0.936170  0.083333
# 4      0.888889  1.000000  0.941176           0.075000  1.000000  0.187500
# ...         ...       ...       ...                ...       ...       ...
# 95     0.985294  0.930556  0.957143           0.050000  0.903846  0.020833
# 96     0.960000  1.000000  0.979592           0.025000  1.000000  0.062500
# 97     0.945946  0.972222  0.958904           0.050000  0.956522  0.083333
# 98     0.923077  1.000000  0.960000           0.050000  1.000000  0.125000
# 99     0.946667  0.986111  0.965986           0.041667  0.977778  0.083333
#
#       specificity  prevalence imputation
# RUN#
# 0        0.916667         0.6     random
# 1        0.937500         0.6     random
# 2        0.979167         0.6     random
# 3        0.916667         0.6     random
# 4        0.812500         0.6     random
# ...           ...         ...        ...
# 95       0.979167         0.6     random
# 96       0.937500         0.6     random
# 97       0.916667         0.6     random
# 98       0.875000         0.6     random
# 99       0.916667         0.6     random
#
# [100 rows x 14 columns]
# DecisionTreeClassifier-GridSearchCV model run statistics:
# ====================================================================================================
#        true_positive  true_negative  false_negative  false_postive  \
# count      100.00000     100.000000       100.00000     100.000000
# mean        69.96000      44.140000         2.04000       3.860000
# std          2.35239       2.113067         2.35239       2.113067
# min         55.00000      39.000000         0.00000       0.000000
# 25%         69.00000      43.000000         0.00000       2.000000
# 50%         71.00000      45.000000         1.00000       3.000000
# 75%         72.00000      46.000000         3.00000       5.000000
# max         72.00000      48.000000        17.00000       9.000000
#
#          accuracy   precision      recall    f1_score  misclassification  \
# count  100.000000  100.000000  100.000000  100.000000         100.000000
# mean     0.950833    0.948561    0.971667    0.959450           0.049167
# std      0.024027    0.026457    0.032672    0.020477           0.024027
# min      0.841667    0.887500    0.763889    0.852713           0.008333
# 25%      0.933333    0.933108    0.958333    0.946486           0.033333
# 50%      0.950000    0.957143    0.986111    0.960000           0.050000
# 75%      0.966667    0.971014    1.000000    0.972973           0.066667
# max      0.991667    1.000000    1.000000    0.993103           0.158333
#
#               npv         fpr  specificity  prevalence
# count  100.000000  100.000000   100.000000       100.0
# mean     0.958218    0.080417     0.919583         0.6
# std      0.042941    0.044022     0.044022         0.0
# min      0.730159    0.000000     0.812500         0.6
# 25%      0.935823    0.041667     0.895833         0.6
# 50%      0.975900    0.062500     0.937500         0.6
# 75%      1.000000    0.104167     0.958333         0.6
# max      1.000000    0.187500     1.000000         0.6
# RandomForestClassifier model runs:
# ====================================================================================================
#       true_positive  true_negative  false_negative  false_postive  accuracy  \
# RUN#
# 0                72             45               0              3  0.975000
# 1                72             46               0              2  0.983333
# 2                71             48               1              0  0.991667
# 3                72             44               0              4  0.966667
# 4                72             44               0              4  0.966667
# ...             ...            ...             ...            ...       ...
# 95               72             45               0              3  0.975000
# 96               72             44               0              4  0.966667
# 97               72             45               0              3  0.975000
# 98               72             42               0              6  0.950000
# 99               72             46               0              2  0.983333
#
#       precision    recall  f1_score  misclassification       npv       fpr  \
# RUN#
# 0      0.960000  1.000000  0.979592           0.025000  1.000000  0.062500
# 1      0.972973  1.000000  0.986301           0.016667  1.000000  0.041667
# 2      1.000000  0.986111  0.993007           0.008333  0.979592  0.000000
# 3      0.947368  1.000000  0.972973           0.033333  1.000000  0.083333
# 4      0.947368  1.000000  0.972973           0.033333  1.000000  0.083333
# ...         ...       ...       ...                ...       ...       ...
# 95     0.960000  1.000000  0.979592           0.025000  1.000000  0.062500
# 96     0.947368  1.000000  0.972973           0.033333  1.000000  0.083333
# 97     0.960000  1.000000  0.979592           0.025000  1.000000  0.062500
# 98     0.923077  1.000000  0.960000           0.050000  1.000000  0.125000
# 99     0.972973  1.000000  0.986301           0.016667  1.000000  0.041667
#
#       specificity  prevalence imputation
# RUN#
# 0        0.937500         0.6     random
# 1        0.958333         0.6     random
# 2        1.000000         0.6     random
# 3        0.916667         0.6     random
# 4        0.916667         0.6     random
# ...           ...         ...        ...
# 95       0.937500         0.6     random
# 96       0.916667         0.6     random
# 97       0.937500         0.6     random
# 98       0.875000         0.6     random
# 99       0.958333         0.6     random
#
# [100 rows x 14 columns]
# RandomForestClassifier model run statistics:
# ====================================================================================================
#        true_positive  true_negative  false_negative  false_postive  \
# count     100.000000     100.000000      100.000000     100.000000
# mean       71.840000      44.920000        0.160000       3.080000
# std         0.368453       1.488542        0.368453       1.488542
# min        71.000000      41.000000        0.000000       0.000000
# 25%        72.000000      44.000000        0.000000       2.000000
# 50%        72.000000      45.000000        0.000000       3.000000
# 75%        72.000000      46.000000        0.000000       4.000000
# max        72.000000      48.000000        1.000000       7.000000
#
#          accuracy   precision      recall    f1_score  misclassification  \
# count  100.000000  100.000000  100.000000  100.000000         100.000000
# mean     0.973000    0.959267    0.997778    0.978040           0.027000
# std      0.012542    0.018887    0.005117    0.009995           0.012542
# min      0.933333    0.910256    0.986111    0.946667           0.008333
# 25%      0.966667    0.947368    1.000000    0.972973           0.016667
# 50%      0.975000    0.960000    1.000000    0.979451           0.025000
# 75%      0.983333    0.972973    1.000000    0.986301           0.033333
# max      0.991667    1.000000    1.000000    0.993103           0.066667
#
#               npv         fpr  specificity  prevalence
# count  100.000000  100.000000   100.000000       100.0
# mean     0.996532    0.064167     0.935833         0.6
# std      0.007992    0.031011     0.031011         0.0
# min      0.976190    0.000000     0.854167         0.6
# 25%      1.000000    0.041667     0.916667         0.6
# 50%      1.000000    0.062500     0.937500         0.6
# 75%      1.000000    0.083333     0.958333         0.6
# max      1.000000    0.145833     1.000000         0.6
# XGBClassifier model runs:
# ====================================================================================================
#       true_positive  true_negative  false_negative  false_postive  accuracy  \
# RUN#
# 0                72             43               0              5  0.958333
# 1                71             46               1              2  0.975000
# 2                71             48               1              0  0.991667
# 3                72             45               0              3  0.975000
# 4                72             45               0              3  0.975000
# ...             ...            ...             ...            ...       ...
# 95               71             46               1              2  0.975000
# 96               72             47               0              1  0.991667
# 97               72             45               0              3  0.975000
# 98               72             44               0              4  0.966667
# 99               72             46               0              2  0.983333
#
#       precision    recall  f1_score  misclassification       npv       fpr  \
# RUN#
# 0      0.935065  1.000000  0.966443           0.041667  1.000000  0.104167
# 1      0.972603  0.986111  0.979310           0.025000  0.978723  0.041667
# 2      1.000000  0.986111  0.993007           0.008333  0.979592  0.000000
# 3      0.960000  1.000000  0.979592           0.025000  1.000000  0.062500
# 4      0.960000  1.000000  0.979592           0.025000  1.000000  0.062500
# ...         ...       ...       ...                ...       ...       ...
# 95     0.972603  0.986111  0.979310           0.025000  0.978723  0.041667
# 96     0.986301  1.000000  0.993103           0.008333  1.000000  0.020833
# 97     0.960000  1.000000  0.979592           0.025000  1.000000  0.062500
# 98     0.947368  1.000000  0.972973           0.033333  1.000000  0.083333
# 99     0.972973  1.000000  0.986301           0.016667  1.000000  0.041667
#
#       specificity  prevalence imputation
# RUN#
# 0        0.895833         0.6     random
# 1        0.958333         0.6     random
# 2        1.000000         0.6     random
# 3        0.937500         0.6     random
# 4        0.937500         0.6     random
# ...           ...         ...        ...
# 95       0.958333         0.6     random
# 96       0.979167         0.6     random
# 97       0.937500         0.6     random
# 98       0.916667         0.6     random
# 99       0.958333         0.6     random
#
# [100 rows x 14 columns]
# XGBClassifier model run statistics:
# ====================================================================================================
#        true_positive  true_negative  false_negative  false_postive  \
# count     100.000000     100.000000      100.000000     100.000000
# mean       71.570000      45.340000        0.430000       2.660000
# std         0.590412       1.464875        0.590412       1.464875
# min        70.000000      42.000000        0.000000       0.000000
# 25%        71.000000      44.000000        0.000000       1.000000
# 50%        72.000000      45.000000        0.000000       3.000000
# 75%        72.000000      47.000000        1.000000       4.000000
# max        72.000000      48.000000        2.000000       6.000000
#
#          accuracy   precision      recall    f1_score  misclassification  \
# count  100.000000  100.000000  100.000000  100.000000         100.000000
# mean     0.974250    0.964556    0.994028    0.978949           0.025750
# std      0.012484    0.018984    0.008200    0.010075           0.012484
# min      0.941667    0.922078    0.972222    0.953020           0.000000
# 25%      0.966667    0.947368    0.986111    0.972603           0.016667
# 50%      0.975000    0.960000    1.000000    0.979592           0.025000
# 75%      0.983333    0.986111    1.000000    0.986301           0.033333
# max      1.000000    1.000000    1.000000    1.000000           0.058333
#
#               npv         fpr  specificity  prevalence
# count  100.000000  100.000000   100.000000       100.0
# mean     0.990815    0.055417     0.944583         0.6
# std      0.012591    0.030518     0.030518         0.0
# min      0.956522    0.000000     0.875000         0.6
# 25%      0.978723    0.020833     0.916667         0.6
# 50%      1.000000    0.062500     0.937500         0.6
# 75%      1.000000    0.083333     0.979167         0.6
# max      1.000000    0.125000     1.000000         0.6
# LogisticRegression model runs:
# ====================================================================================================
#       true_positive  true_negative  false_negative  false_postive  accuracy  \
# RUN#
# 0                68             45               4              3  0.941667
# 1                66             46               6              2  0.933333
# 2                69             46               3              2  0.958333
# 3                69             45               3              3  0.950000
# 4                67             46               5              2  0.941667
# ...             ...            ...             ...            ...       ...
# 95               69             45               3              3  0.950000
# 96               71             46               1              2  0.975000
# 97               70             46               2              2  0.966667
# 98               70             46               2              2  0.966667
# 99               71             46               1              2  0.975000
#
#       precision    recall  f1_score  misclassification       npv       fpr  \
# RUN#
# 0      0.957746  0.944444  0.951049           0.058333  0.918367  0.062500
# 1      0.970588  0.916667  0.942857           0.066667  0.884615  0.041667
# 2      0.971831  0.958333  0.965035           0.041667  0.938776  0.041667
# 3      0.958333  0.958333  0.958333           0.050000  0.937500  0.062500
# 4      0.971014  0.930556  0.950355           0.058333  0.901961  0.041667
# ...         ...       ...       ...                ...       ...       ...
# 95     0.958333  0.958333  0.958333           0.050000  0.937500  0.062500
# 96     0.972603  0.986111  0.979310           0.025000  0.978723  0.041667
# 97     0.972222  0.972222  0.972222           0.033333  0.958333  0.041667
# 98     0.972222  0.972222  0.972222           0.033333  0.958333  0.041667
# 99     0.972603  0.986111  0.979310           0.025000  0.978723  0.041667
#
#       specificity  prevalence imputation
# RUN#
# 0        0.937500         0.6     random
# 1        0.958333         0.6     random
# 2        0.958333         0.6     random
# 3        0.937500         0.6     random
# 4        0.958333         0.6     random
# ...           ...         ...        ...
# 95       0.937500         0.6     random
# 96       0.958333         0.6     random
# 97       0.958333         0.6     random
# 98       0.958333         0.6     random
# 99       0.958333         0.6     random
#
# [100 rows x 14 columns]
# LogisticRegression model run statistics:
# ====================================================================================================
#        true_positive  true_negative  false_negative  false_postive  \
# count     100.000000     100.000000      100.000000     100.000000
# mean       69.050000      45.860000        2.950000       2.140000
# std         1.122542       1.247381        1.122542       1.247381
# min        66.000000      42.000000        1.000000       0.000000
# 25%        68.000000      45.000000        2.000000       1.000000
# 50%        69.000000      46.000000        3.000000       2.000000
# 75%        70.000000      47.000000        4.000000       3.000000
# max        71.000000      48.000000        6.000000       6.000000
#
#          accuracy   precision      recall    f1_score  misclassification  \
# count  100.000000  100.000000  100.000000  100.000000         100.000000
# mean     0.957583    0.970230    0.959028    0.964462           0.042417
# std      0.013868    0.016896    0.015591    0.011573           0.013868
# min      0.925000    0.920000    0.916667    0.937063           0.016667
# 25%      0.947917    0.958333    0.944444    0.955952           0.033333
# 50%      0.958333    0.971831    0.958333    0.965035           0.041667
# 75%      0.966667    0.985714    0.972222    0.972222           0.052083
# max      0.983333    1.000000    0.986111    0.985915           0.075000
#
#               npv         fpr  specificity  prevalence
# count  100.000000  100.000000   100.000000       100.0
# mean     0.940017    0.044583     0.955417         0.6
# std      0.021481    0.025987     0.025987         0.0
# min      0.884615    0.000000     0.875000         0.6
# 25%      0.922700    0.020833     0.937500         0.6
# 50%      0.939388    0.041667     0.958333         0.6
# 75%      0.958333    0.062500     0.979167         0.6
# max      0.978723    0.125000     1.000000         0.6
