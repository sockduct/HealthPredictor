# %% [markdown]
# # Analyze HealthPredictor Notebook Runs

# %%
# Standard Library:
from collections import defaultdict
import shelve

# 3rd Party:
from IPython.display import display as display
import pandas as pd

# Shelve Database:
DB = 'hp_results'

# %%
# Load the shelve database
with shelve.open(DB) as db:
    # Create a dictionary to group runs by model
    model_data = defaultdict(dict)

    for full_key, metrics in db.items():
        # Split into run and model
        run, model = full_key.split('/', 1)
        model_data[model][run] = metrics

# Now convert each model's runs into a DataFrame
model_dfs = {}

for model, runs in model_data.items():
    df = pd.DataFrame.from_dict(runs, orient='index')
    df.index.name = 'RUN#'
    model_dfs[model] = df

# Now model_dfs is a dictionary: model name -> corresponding DataFrame
for model in model_dfs:
    print(f'{model} model runs:\n{'=' * 100}')
    display(model_dfs[model])
    print(f'{model} model run statistics:\n{'=' * 100}')
    display(model_dfs[model].describe())
# Out:
# DecisionTreeClassifier model runs:
# ====================================================================================================
#       accuracy  precision    recall  f1_score  misclassification       npv  \
# RUN#
# 0     0.933333   0.957143  0.930556  0.943662           0.066667  0.900000
# 1     0.950000   0.958333  0.958333  0.958333           0.050000  0.937500
# 2     0.933333   0.957143  0.930556  0.943662           0.066667  0.900000
# 3     0.933333   0.957143  0.930556  0.943662           0.066667  0.900000
# 4     0.933333   0.957143  0.930556  0.943662           0.066667  0.900000
# 5     0.941667   0.957746  0.944444  0.951049           0.058333  0.918367
# 6     0.950000   0.958333  0.958333  0.958333           0.050000  0.937500
# 7     0.933333   0.957143  0.930556  0.943662           0.066667  0.900000
# 8     0.941667   0.957746  0.944444  0.951049           0.058333  0.918367
# 9     0.933333   0.957143  0.930556  0.943662           0.066667  0.900000
#
#          fpr  specificity  prevalence imputation
# RUN#
# 0     0.0625       0.9375         0.6        knn
# 1     0.0625       0.9375         0.6        knn
# 2     0.0625       0.9375         0.6        knn
# 3     0.0625       0.9375         0.6        knn
# 4     0.0625       0.9375         0.6        knn
# 5     0.0625       0.9375         0.6        knn
# 6     0.0625       0.9375         0.6        knn
# 7     0.0625       0.9375         0.6        knn
# 8     0.0625       0.9375         0.6        knn
# 9     0.0625       0.9375         0.6        knn
# DecisionTreeClassifier model run statistics:
# ====================================================================================================
#         accuracy  precision     recall   f1_score  misclassification  \
# count  10.000000  10.000000  10.000000  10.000000          10.000000
# mean    0.938333   0.957502   0.938889   0.948074           0.061667
# std     0.007027   0.000503   0.011712   0.006191           0.007027
# min     0.933333   0.957143   0.930556   0.943662           0.050000
# 25%     0.933333   0.957143   0.930556   0.943662           0.058333
# 50%     0.933333   0.957143   0.930556   0.943662           0.066667
# 75%     0.941667   0.957746   0.944444   0.951049           0.066667
# max     0.950000   0.958333   0.958333   0.958333           0.066667
#
#              npv      fpr  specificity    prevalence
# count  10.000000  10.0000      10.0000  1.000000e+01
# mean    0.911173   0.0625       0.9375  6.000000e-01
# std     0.015772   0.0000       0.0000  1.170278e-16
# min     0.900000   0.0625       0.9375  6.000000e-01
# 25%     0.900000   0.0625       0.9375  6.000000e-01
# 50%     0.900000   0.0625       0.9375  6.000000e-01
# 75%     0.918367   0.0625       0.9375  6.000000e-01
# max     0.937500   0.0625       0.9375  6.000000e-01
# DecisionTreeClassifier-GridSearchCV model runs:
# ====================================================================================================
#       accuracy  precision    recall  f1_score  misclassification       npv  \
# RUN#
# 0     1.000000   1.000000  1.000000  1.000000           0.000000  1.000000
# 1     0.950000   0.958333  0.958333  0.958333           0.050000  0.937500
# 2     0.958333   0.958904  0.972222  0.965517           0.041667  0.957447
# 3     0.975000   0.960000  1.000000  0.979592           0.025000  1.000000
# 4     0.941667   0.945205  0.958333  0.951724           0.058333  0.936170
# 5     0.925000   0.984615  0.888889  0.934307           0.075000  0.854545
# 6     0.916667   0.930556  0.930556  0.930556           0.083333  0.895833
# 7     0.950000   0.971429  0.944444  0.957746           0.050000  0.920000
# 8     0.916667   0.918919  0.944444  0.931507           0.083333  0.913043
# 9     0.950000   0.971429  0.944444  0.957746           0.050000  0.920000
#
#            fpr  specificity  prevalence imputation
# RUN#
# 0     0.000000     1.000000         0.6        knn
# 1     0.062500     0.937500         0.6        knn
# 2     0.062500     0.937500         0.6        knn
# 3     0.062500     0.937500         0.6        knn
# 4     0.083333     0.916667         0.6        knn
# 5     0.020833     0.979167         0.6        knn
# 6     0.104167     0.895833         0.6        knn
# 7     0.041667     0.958333         0.6        knn
# 8     0.125000     0.875000         0.6        knn
# 9     0.041667     0.958333         0.6        knn
# DecisionTreeClassifier-GridSearchCV model run statistics:
# ====================================================================================================
#         accuracy  precision     recall   f1_score  misclassification  \
# count  10.000000  10.000000  10.000000  10.000000          10.000000
# mean    0.948333   0.959939   0.954167   0.956703           0.051667
# std     0.025999   0.024140   0.032769   0.021924           0.025999
# min     0.916667   0.918919   0.888889   0.930556           0.000000
# 25%     0.929167   0.948487   0.944444   0.938661           0.043750
# 50%     0.950000   0.959452   0.951389   0.957746           0.050000
# 75%     0.956250   0.971429   0.968750   0.963721           0.070833
# max     1.000000   1.000000   1.000000   1.000000           0.083333
#
#              npv        fpr  specificity    prevalence
# count  10.000000  10.000000    10.000000  1.000000e+01
# mean    0.933454   0.060417     0.939583  6.000000e-01
# std     0.044568   0.037332     0.037332  1.170278e-16
# min     0.854545   0.000000     0.875000  6.000000e-01
# 25%     0.914783   0.041667     0.921875  6.000000e-01
# 50%     0.928085   0.062500     0.937500  6.000000e-01
# 75%     0.952460   0.078125     0.958333  6.000000e-01
# max     1.000000   0.125000     1.000000  6.000000e-01
# RandomForestClassifier model runs:
# ====================================================================================================
#       accuracy  precision    recall  f1_score  misclassification       npv  \
# RUN#
# 0     1.000000   1.000000  1.000000  1.000000           0.000000  1.000000
# 1     1.000000   1.000000  1.000000  1.000000           0.000000  1.000000
# 2     0.966667   0.947368  1.000000  0.972973           0.033333  1.000000
# 3     1.000000   1.000000  1.000000  1.000000           0.000000  1.000000
# 4     0.975000   0.960000  1.000000  0.979592           0.025000  1.000000
# 5     0.966667   0.947368  1.000000  0.972973           0.033333  1.000000
# 6     0.958333   0.946667  0.986111  0.965986           0.041667  0.977778
# 7     0.991667   0.986301  1.000000  0.993103           0.008333  1.000000
# 8     0.991667   1.000000  0.986111  0.993007           0.008333  0.979592
# 9     1.000000   1.000000  1.000000  1.000000           0.000000  1.000000
#
#            fpr  specificity  prevalence imputation
# RUN#
# 0     0.000000     1.000000         0.6        knn
# 1     0.000000     1.000000         0.6        knn
# 2     0.083333     0.916667         0.6        knn
# 3     0.000000     1.000000         0.6        knn
# 4     0.062500     0.937500         0.6        knn
# 5     0.083333     0.916667         0.6        knn
# 6     0.083333     0.916667         0.6        knn
# 7     0.020833     0.979167         0.6        knn
# 8     0.000000     1.000000         0.6        knn
# 9     0.000000     1.000000         0.6        knn
# RandomForestClassifier model run statistics:
# ====================================================================================================
#         accuracy  precision     recall   f1_score  misclassification  \
# count  10.000000  10.000000  10.000000  10.000000          10.000000
# mean    0.985000   0.978770   0.997222   0.987763           0.015000
# std     0.016574   0.025089   0.005856   0.013472           0.016574
# min     0.958333   0.946667   0.986111   0.965986           0.000000
# 25%     0.968750   0.950526   1.000000   0.974628           0.000000
# 50%     0.991667   0.993151   1.000000   0.993055           0.008333
# 75%     1.000000   1.000000   1.000000   1.000000           0.031250
# max     1.000000   1.000000   1.000000   1.000000           0.041667
#
#              npv        fpr  specificity    prevalence
# count  10.000000  10.000000    10.000000  1.000000e+01
# mean    0.995737   0.033333     0.966667  6.000000e-01
# std     0.008997   0.039528     0.039528  1.170278e-16
# min     0.977778   0.000000     0.916667  6.000000e-01
# 25%     1.000000   0.000000     0.921875  6.000000e-01
# 50%     1.000000   0.010417     0.989583  6.000000e-01
# 75%     1.000000   0.078125     1.000000  6.000000e-01
# max     1.000000   0.083333     1.000000  6.000000e-01
# XGBClassifier model runs:
# ====================================================================================================
#       accuracy  precision  recall  f1_score  misclassification  npv       fpr  \
# RUN#
# 0     0.991667   0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 1     0.991667   0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 2     0.991667   0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 3     0.991667   0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 4     0.991667   0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 5     0.991667   0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 6     0.991667   0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 7     0.991667   0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 8     0.991667   0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 9     0.991667   0.986301     1.0  0.993103           0.008333  1.0  0.020833
#
#       specificity  prevalence imputation
# RUN#
# 0        0.979167         0.6        knn
# 1        0.979167         0.6        knn
# 2        0.979167         0.6        knn
# 3        0.979167         0.6        knn
# 4        0.979167         0.6        knn
# 5        0.979167         0.6        knn
# 6        0.979167         0.6        knn
# 7        0.979167         0.6        knn
# 8        0.979167         0.6        knn
# 9        0.979167         0.6        knn
# XGBClassifier model run statistics:
# ====================================================================================================
#            accuracy     precision  recall   f1_score  misclassification   npv  \
# count  1.000000e+01  1.000000e+01    10.0  10.000000          10.000000  10.0
# mean   9.916667e-01  9.863014e-01     1.0   0.993103           0.008333   1.0
# std    1.170278e-16  1.170278e-16     0.0   0.000000           0.000000   0.0
# min    9.916667e-01  9.863014e-01     1.0   0.993103           0.008333   1.0
# 25%    9.916667e-01  9.863014e-01     1.0   0.993103           0.008333   1.0
# 50%    9.916667e-01  9.863014e-01     1.0   0.993103           0.008333   1.0
# 75%    9.916667e-01  9.863014e-01     1.0   0.993103           0.008333   1.0
# max    9.916667e-01  9.863014e-01     1.0   0.993103           0.008333   1.0
#
#                 fpr  specificity    prevalence
# count  1.000000e+01    10.000000  1.000000e+01
# mean   2.083333e-02     0.979167  6.000000e-01
# std    3.657118e-18     0.000000  1.170278e-16
# min    2.083333e-02     0.979167  6.000000e-01
# 25%    2.083333e-02     0.979167  6.000000e-01
# 50%    2.083333e-02     0.979167  6.000000e-01
# 75%    2.083333e-02     0.979167  6.000000e-01
# max    2.083333e-02     0.979167  6.000000e-01
# LogisticRegression model runs:
# ====================================================================================================
#       accuracy  precision    recall  f1_score  misclassification       npv  \
# RUN#
# 0        0.975        1.0  0.958333  0.978723              0.025  0.941176
# 1        0.975        1.0  0.958333  0.978723              0.025  0.941176
# 2        0.975        1.0  0.958333  0.978723              0.025  0.941176
# 3        0.975        1.0  0.958333  0.978723              0.025  0.941176
# 4        0.975        1.0  0.958333  0.978723              0.025  0.941176
# 5        0.975        1.0  0.958333  0.978723              0.025  0.941176
# 6        0.975        1.0  0.958333  0.978723              0.025  0.941176
# 7        0.975        1.0  0.958333  0.978723              0.025  0.941176
# 8        0.975        1.0  0.958333  0.978723              0.025  0.941176
# 9        0.975        1.0  0.958333  0.978723              0.025  0.941176
#
#       fpr  specificity  prevalence imputation
# RUN#
# 0     0.0          1.0         0.6        knn
# 1     0.0          1.0         0.6        knn
# 2     0.0          1.0         0.6        knn
# 3     0.0          1.0         0.6        knn
# 4     0.0          1.0         0.6        knn
# 5     0.0          1.0         0.6        knn
# 6     0.0          1.0         0.6        knn
# 7     0.0          1.0         0.6        knn
# 8     0.0          1.0         0.6        knn
# 9     0.0          1.0         0.6        knn
# LogisticRegression model run statistics:
# ====================================================================================================
#        accuracy  precision     recall   f1_score  misclassification  \
# count    10.000       10.0  10.000000  10.000000             10.000
# mean      0.975        1.0   0.958333   0.978723              0.025
# std       0.000        0.0   0.000000   0.000000              0.000
# min       0.975        1.0   0.958333   0.978723              0.025
# 25%       0.975        1.0   0.958333   0.978723              0.025
# 50%       0.975        1.0   0.958333   0.978723              0.025
# 75%       0.975        1.0   0.958333   0.978723              0.025
# max       0.975        1.0   0.958333   0.978723              0.025
#
#              npv   fpr  specificity    prevalence
# count  10.000000  10.0         10.0  1.000000e+01
# mean    0.941176   0.0          1.0  6.000000e-01
# std     0.000000   0.0          0.0  1.170278e-16
# min     0.941176   0.0          1.0  6.000000e-01
# 25%     0.941176   0.0          1.0  6.000000e-01
# 50%     0.941176   0.0          1.0  6.000000e-01
# 75%     0.941176   0.0          1.0  6.000000e-01
# max     0.941176   0.0          1.0  6.000000e-01
