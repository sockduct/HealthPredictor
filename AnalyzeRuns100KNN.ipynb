# %% [markdown]
# # Analyze HealthPredictor Notebook Runs

# %%
# Standard Library:
from collections import defaultdict
import shelve

# 3rd Party:
from IPython.display import display as display
import pandas as pd

# Shelve Database:
DB = 'hp_results'

# %%
# Load the shelve database
with shelve.open(DB) as db:
    # Create a dictionary to group runs by model
    model_data = defaultdict(dict)

    for full_key, metrics in db.items():
        # Split into run and model
        run, model = full_key.split('/', 1)
        model_data[model][run] = metrics

# Now convert each model's runs into a DataFrame
model_dfs = {}

for model, runs in model_data.items():
    df = pd.DataFrame.from_dict(runs, orient='index')
    df.index.name = 'RUN#'
    model_dfs[model] = df

# Now model_dfs is a dictionary: model name -> corresponding DataFrame
for model in model_dfs:
    print(f'{model} model runs:\n{'=' * 100}')
    display(model_dfs[model])
    print(f'{model} model run statistics:\n{'=' * 100}')
    display(model_dfs[model].describe())
# Out:
# DecisionTreeClassifier model runs:
# ====================================================================================================
#       accuracy  precision    recall  f1_score  misclassification       npv  \
# RUN#
# 0     0.933333   0.957143  0.930556  0.943662           0.066667  0.900000
# 1     0.933333   0.957143  0.930556  0.943662           0.066667  0.900000
# 2     0.950000   0.958333  0.958333  0.958333           0.050000  0.937500
# 3     0.941667   0.957746  0.944444  0.951049           0.058333  0.918367
# 4     0.950000   0.958333  0.958333  0.958333           0.050000  0.937500
# ...        ...        ...       ...       ...                ...       ...
# 95    0.941667   0.957746  0.944444  0.951049           0.058333  0.918367
# 96    0.941667   0.957746  0.944444  0.951049           0.058333  0.918367
# 97    0.941667   0.957746  0.944444  0.951049           0.058333  0.918367
# 98    0.933333   0.957143  0.930556  0.943662           0.066667  0.900000
# 99    0.941667   0.957746  0.944444  0.951049           0.058333  0.918367
#
#          fpr  specificity  prevalence imputation
# RUN#
# 0     0.0625       0.9375         0.6        knn
# 1     0.0625       0.9375         0.6        knn
# 2     0.0625       0.9375         0.6        knn
# 3     0.0625       0.9375         0.6        knn
# 4     0.0625       0.9375         0.6        knn
# ...      ...          ...         ...        ...
# 95    0.0625       0.9375         0.6        knn
# 96    0.0625       0.9375         0.6        knn
# 97    0.0625       0.9375         0.6        knn
# 98    0.0625       0.9375         0.6        knn
# 99    0.0625       0.9375         0.6        knn
#
# [100 rows x 10 columns]
# DecisionTreeClassifier model run statistics:
# ====================================================================================================
#          accuracy   precision      recall    f1_score  misclassification  \
# count  100.000000  100.000000  100.000000  100.000000         100.000000
# mean     0.941000    0.957695    0.943333    0.950437           0.059000
# std      0.005764    0.000412    0.009606    0.005077           0.005764
# min      0.933333    0.957143    0.930556    0.943662           0.050000
# 25%      0.933333    0.957143    0.930556    0.943662           0.058333
# 50%      0.941667    0.957746    0.944444    0.951049           0.058333
# 75%      0.941667    0.957746    0.944444    0.951049           0.066667
# max      0.950000    0.958333    0.958333    0.958333           0.066667
#
#               npv       fpr  specificity  prevalence
# count  100.000000  100.0000     100.0000       100.0
# mean     0.917051    0.0625       0.9375         0.6
# std      0.012947    0.0000       0.0000         0.0
# min      0.900000    0.0625       0.9375         0.6
# 25%      0.900000    0.0625       0.9375         0.6
# 50%      0.918367    0.0625       0.9375         0.6
# 75%      0.918367    0.0625       0.9375         0.6
# max      0.937500    0.0625       0.9375         0.6
# DecisionTreeClassifier-GridSearchCV model runs:
# ====================================================================================================
#       accuracy  precision    recall  f1_score  misclassification       npv  \
# RUN#
# 0     0.875000   0.860759  0.944444  0.900662           0.125000  0.902439
# 1     0.925000   1.000000  0.875000  0.933333           0.075000  0.842105
# 2     0.908333   0.984127  0.861111  0.918519           0.091667  0.824561
# 3     0.958333   0.946667  0.986111  0.965986           0.041667  0.977778
# 4     0.958333   0.946667  0.986111  0.965986           0.041667  0.977778
# ...        ...        ...       ...       ...                ...       ...
# 95    0.958333   0.971831  0.958333  0.965035           0.041667  0.938776
# 96    0.941667   0.933333  0.972222  0.952381           0.058333  0.955556
# 97    0.941667   0.945205  0.958333  0.951724           0.058333  0.936170
# 98    0.966667   0.947368  1.000000  0.972973           0.033333  1.000000
# 99    0.966667   0.972222  0.972222  0.972222           0.033333  0.958333
#
#            fpr  specificity  prevalence imputation
# RUN#
# 0     0.229167     0.770833         0.6        knn
# 1     0.000000     1.000000         0.6        knn
# 2     0.020833     0.979167         0.6        knn
# 3     0.083333     0.916667         0.6        knn
# 4     0.083333     0.916667         0.6        knn
# ...        ...          ...         ...        ...
# 95    0.041667     0.958333         0.6        knn
# 96    0.104167     0.895833         0.6        knn
# 97    0.083333     0.916667         0.6        knn
# 98    0.083333     0.916667         0.6        knn
# 99    0.041667     0.958333         0.6        knn
#
# [100 rows x 10 columns]
# DecisionTreeClassifier-GridSearchCV model run statistics:
# ====================================================================================================
#          accuracy   precision      recall    f1_score  misclassification  \
# count  100.000000  100.000000  100.000000  100.000000         100.000000
# mean     0.948500    0.953004    0.962917    0.956984           0.051500
# std      0.026941    0.028088    0.044012    0.024798           0.026941
# min      0.791667    0.860759    0.652778    0.789916           0.008333
# 25%      0.933333    0.934211    0.954861    0.945761           0.033333
# 50%      0.958333    0.946667    0.972222    0.964532           0.041667
# 75%      0.966667    0.971929    0.986111    0.971429           0.066667
# max      0.991667    1.000000    1.000000    0.993103           0.208333
#
#               npv         fpr  specificity  prevalence
# count  100.000000  100.000000   100.000000       100.0
# mean     0.947324    0.073125     0.926875         0.6
# std      0.050935    0.045248     0.045248         0.0
# min      0.657534    0.000000     0.770833         0.6
# 25%      0.929633    0.041667     0.895833         0.6
# 50%      0.956984    0.083333     0.916667         0.6
# 75%      0.977778    0.104167     0.958333         0.6
# max      1.000000    0.229167     1.000000         0.6
# RandomForestClassifier model runs:
# ====================================================================================================
#       accuracy  precision  recall  f1_score  misclassification  npv       fpr  \
# RUN#
# 0     0.966667   0.947368     1.0  0.972973           0.033333  1.0  0.083333
# 1     0.991667   0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 2     0.966667   0.947368     1.0  0.972973           0.033333  1.0  0.083333
# 3     1.000000   1.000000     1.0  1.000000           0.000000  1.0  0.000000
# 4     1.000000   1.000000     1.0  1.000000           0.000000  1.0  0.000000
# ...        ...        ...     ...       ...                ...  ...       ...
# 95    0.966667   0.947368     1.0  0.972973           0.033333  1.0  0.083333
# 96    0.966667   0.947368     1.0  0.972973           0.033333  1.0  0.083333
# 97    0.983333   0.972973     1.0  0.986301           0.016667  1.0  0.041667
# 98    0.966667   0.947368     1.0  0.972973           0.033333  1.0  0.083333
# 99    0.966667   0.947368     1.0  0.972973           0.033333  1.0  0.083333
#
#       specificity  prevalence imputation
# RUN#
# 0        0.916667         0.6        knn
# 1        0.979167         0.6        knn
# 2        0.916667         0.6        knn
# 3        1.000000         0.6        knn
# 4        1.000000         0.6        knn
# ...           ...         ...        ...
# 95       0.916667         0.6        knn
# 96       0.916667         0.6        knn
# 97       0.958333         0.6        knn
# 98       0.916667         0.6        knn
# 99       0.916667         0.6        knn
#
# [100 rows x 10 columns]
# RandomForestClassifier model run statistics:
# ====================================================================================================
#          accuracy   precision      recall    f1_score  misclassification  \
# count  100.000000  100.000000  100.000000  100.000000         100.000000
# mean     0.982000    0.971568    0.999722    0.985330           0.018000
# std      0.013068    0.020692    0.001954    0.010582           0.013068
# min      0.966667    0.947368    0.986111    0.972973           0.000000
# 25%      0.966667    0.947368    1.000000    0.972973           0.008333
# 50%      0.983333    0.972973    1.000000    0.986301           0.016667
# 75%      0.991667    0.986301    1.000000    0.993103           0.033333
# max      1.000000    1.000000    1.000000    1.000000           0.033333
#
#               npv         fpr  specificity  prevalence
# count  100.000000  100.000000   100.000000       100.0
# mean     0.999583    0.044583     0.955417         0.6
# std      0.002933    0.032843     0.032843         0.0
# min      0.978723    0.000000     0.916667         0.6
# 25%      1.000000    0.020833     0.916667         0.6
# 50%      1.000000    0.041667     0.958333         0.6
# 75%      1.000000    0.083333     0.979167         0.6
# max      1.000000    0.083333     1.000000         0.6
# XGBClassifier model runs:
# ====================================================================================================
#       accuracy  precision    recall  f1_score  misclassification       npv  \
# RUN#
# 0     0.991667   0.986301  1.000000  0.993103           0.008333  1.000000
# 1     0.991667   0.986301  1.000000  0.993103           0.008333  1.000000
# 2     0.991667   0.986301  1.000000  0.993103           0.008333  1.000000
# 3     0.991667   0.986301  1.000000  0.993103           0.008333  1.000000
# 4     0.991667   0.986301  1.000000  0.993103           0.008333  1.000000
# ...        ...        ...       ...       ...                ...       ...
# 95    0.991667   0.986301  1.000000  0.993103           0.008333  1.000000
# 96    0.991667   0.986301  1.000000  0.993103           0.008333  1.000000
# 97    0.991667   0.986301  1.000000  0.993103           0.008333  1.000000
# 98    0.983333   0.986111  0.986111  0.986111           0.016667  0.979167
# 99    0.991667   0.986301  1.000000  0.993103           0.008333  1.000000
#
#            fpr  specificity  prevalence imputation
# RUN#
# 0     0.020833     0.979167         0.6        knn
# 1     0.020833     0.979167         0.6        knn
# 2     0.020833     0.979167         0.6        knn
# 3     0.020833     0.979167         0.6        knn
# 4     0.020833     0.979167         0.6        knn
# ...        ...          ...         ...        ...
# 95    0.020833     0.979167         0.6        knn
# 96    0.020833     0.979167         0.6        knn
# 97    0.020833     0.979167         0.6        knn
# 98    0.020833     0.979167         0.6        knn
# 99    0.020833     0.979167         0.6        knn
#
# [100 rows x 10 columns]
# XGBClassifier model run statistics:
# ====================================================================================================
#          accuracy   precision      recall    f1_score  misclassification  \
# count  100.000000  100.000000  100.000000  100.000000         100.000000
# mean     0.991667    0.986436    0.999861    0.993102           0.008333
# std      0.001184    0.001370    0.001389    0.000987           0.001184
# min      0.983333    0.986111    0.986111    0.986111           0.000000
# 25%      0.991667    0.986301    1.000000    0.993103           0.008333
# 50%      0.991667    0.986301    1.000000    0.993103           0.008333
# 75%      0.991667    0.986301    1.000000    0.993103           0.008333
# max      1.000000    1.000000    1.000000    1.000000           0.016667
#
#               npv         fpr  specificity  prevalence
# count  100.000000  100.000000   100.000000       100.0
# mean     0.999792    0.020625     0.979375         0.6
# std      0.002083    0.002083     0.002083         0.0
# min      0.979167    0.000000     0.979167         0.6
# 25%      1.000000    0.020833     0.979167         0.6
# 50%      1.000000    0.020833     0.979167         0.6
# 75%      1.000000    0.020833     0.979167         0.6
# max      1.000000    0.020833     1.000000         0.6
# LogisticRegression model runs:
# ====================================================================================================
#       accuracy  precision    recall  f1_score  misclassification       npv  \
# RUN#
# 0     0.975000        1.0  0.958333  0.978723           0.025000  0.941176
# 1     0.966667        1.0  0.944444  0.971429           0.033333  0.923077
# 2     0.983333        1.0  0.972222  0.985915           0.016667  0.960000
# 3     0.983333        1.0  0.972222  0.985915           0.016667  0.960000
# 4     0.975000        1.0  0.958333  0.978723           0.025000  0.941176
# ...        ...        ...       ...       ...                ...       ...
# 95    0.975000        1.0  0.958333  0.978723           0.025000  0.941176
# 96    0.975000        1.0  0.958333  0.978723           0.025000  0.941176
# 97    0.983333        1.0  0.972222  0.985915           0.016667  0.960000
# 98    0.975000        1.0  0.958333  0.978723           0.025000  0.941176
# 99    0.983333        1.0  0.972222  0.985915           0.016667  0.960000
#
#       fpr  specificity  prevalence imputation
# RUN#
# 0     0.0          1.0         0.6        knn
# 1     0.0          1.0         0.6        knn
# 2     0.0          1.0         0.6        knn
# 3     0.0          1.0         0.6        knn
# 4     0.0          1.0         0.6        knn
# ...   ...          ...         ...        ...
# 95    0.0          1.0         0.6        knn
# 96    0.0          1.0         0.6        knn
# 97    0.0          1.0         0.6        knn
# 98    0.0          1.0         0.6        knn
# 99    0.0          1.0         0.6        knn
#
# [100 rows x 10 columns]
# LogisticRegression model run statistics:
# ====================================================================================================
#          accuracy  precision      recall    f1_score  misclassification  \
# count  100.000000      100.0  100.000000  100.000000         100.000000
# mean     0.977833        1.0    0.963056    0.981161           0.022167
# std      0.005193        0.0    0.008654    0.004480           0.005193
# min      0.966667        1.0    0.944444    0.971429           0.008333
# 25%      0.975000        1.0    0.958333    0.978723           0.016667
# 50%      0.975000        1.0    0.958333    0.978723           0.025000
# 75%      0.983333        1.0    0.972222    0.985915           0.025000
# max      0.991667        1.0    0.986111    0.993007           0.033333
#
#               npv    fpr  specificity  prevalence
# count  100.000000  100.0        100.0       100.0
# mean     0.947636    0.0          1.0         0.6
# std      0.011751    0.0          0.0         0.0
# min      0.923077    0.0          1.0         0.6
# 25%      0.941176    0.0          1.0         0.6
# 50%      0.941176    0.0          1.0         0.6
# 75%      0.960000    0.0          1.0         0.6
# max      0.979592    0.0          1.0         0.6
