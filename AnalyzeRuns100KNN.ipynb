# %% [markdown]
# # Analyze HealthPredictor Notebook Runs

# %%
# Standard Library:
from collections import defaultdict
import shelve

# 3rd Party:
from IPython.display import display as display
import pandas as pd

# Shelve Database:
DB = 'hp_results'

# %%
# Load the shelve database
with shelve.open(DB) as db:
    # Create a dictionary to group runs by model
    model_data = defaultdict(dict)

    for full_key, metrics in db.items():
        # Split into run and model
        run, model = full_key.split('/', 1)
        model_data[model][run] = metrics

# Now convert each model's runs into a DataFrame
model_dfs = {}

for model, runs in model_data.items():
    df = pd.DataFrame.from_dict(runs, orient='index')
    df.index.name = 'RUN#'
    model_dfs[model] = df

# Now model_dfs is a dictionary: model name -> corresponding DataFrame
for model in model_dfs:
    print(f'{model} model runs:\n{'=' * 100}')
    display(model_dfs[model])
    print(f'{model} model run statistics:\n{'=' * 100}')
    display(model_dfs[model].describe())
# Out:
# DecisionTreeClassifier model runs:
# ====================================================================================================
#       true_positive  true_negative  false_negative  false_postive  accuracy  \
# RUN#
# 0                68             45               4              3  0.941667
# 1                68             45               4              3  0.941667
# 2                69             45               3              3  0.950000
# 3                68             45               4              3  0.941667
# 4                67             45               5              3  0.933333
# ...             ...            ...             ...            ...       ...
# 95               68             45               4              3  0.941667
# 96               67             45               5              3  0.933333
# 97               68             45               4              3  0.941667
# 98               67             45               5              3  0.933333
# 99               68             45               4              3  0.941667
#
#       precision    recall  f1_score  misclassification       npv     fpr  \
# RUN#
# 0      0.957746  0.944444  0.951049           0.058333  0.918367  0.0625
# 1      0.957746  0.944444  0.951049           0.058333  0.918367  0.0625
# 2      0.958333  0.958333  0.958333           0.050000  0.937500  0.0625
# 3      0.957746  0.944444  0.951049           0.058333  0.918367  0.0625
# 4      0.957143  0.930556  0.943662           0.066667  0.900000  0.0625
# ...         ...       ...       ...                ...       ...     ...
# 95     0.957746  0.944444  0.951049           0.058333  0.918367  0.0625
# 96     0.957143  0.930556  0.943662           0.066667  0.900000  0.0625
# 97     0.957746  0.944444  0.951049           0.058333  0.918367  0.0625
# 98     0.957143  0.930556  0.943662           0.066667  0.900000  0.0625
# 99     0.957746  0.944444  0.951049           0.058333  0.918367  0.0625
#
#       specificity  prevalence imputation
# RUN#
# 0          0.9375         0.6        knn
# 1          0.9375         0.6        knn
# 2          0.9375         0.6        knn
# 3          0.9375         0.6        knn
# 4          0.9375         0.6        knn
# ...           ...         ...        ...
# 95         0.9375         0.6        knn
# 96         0.9375         0.6        knn
# 97         0.9375         0.6        knn
# 98         0.9375         0.6        knn
# 99         0.9375         0.6        knn
#
# [100 rows x 14 columns]
# DecisionTreeClassifier model run statistics:
# ====================================================================================================
#        true_positive  true_negative  false_negative  false_postive  \
# count     100.000000          100.0      100.000000          100.0
# mean       67.880000           45.0        4.120000            3.0
# std         0.607695            0.0        0.607695            0.0
# min        67.000000           45.0        3.000000            3.0
# 25%        67.750000           45.0        4.000000            3.0
# 50%        68.000000           45.0        4.000000            3.0
# 75%        68.000000           45.0        4.250000            3.0
# max        69.000000           45.0        5.000000            3.0
#
#          accuracy   precision      recall    f1_score  misclassification  \
# count  100.000000  100.000000  100.000000  100.000000         100.000000
# mean     0.940667    0.957672    0.942778    0.950149           0.059333
# std      0.005064    0.000363    0.008440    0.004464           0.005064
# min      0.933333    0.957143    0.930556    0.943662           0.050000
# 25%      0.939583    0.957596    0.940972    0.949202           0.058333
# 50%      0.941667    0.957746    0.944444    0.951049           0.058333
# 75%      0.941667    0.957746    0.944444    0.951049           0.060417
# max      0.950000    0.958333    0.958333    0.958333           0.066667
#
#               npv       fpr  specificity  prevalence
# count  100.000000  100.0000     100.0000       100.0
# mean     0.916263    0.0625       0.9375         0.6
# std      0.011348    0.0000       0.0000         0.0
# min      0.900000    0.0625       0.9375         0.6
# 25%      0.913776    0.0625       0.9375         0.6
# 50%      0.918367    0.0625       0.9375         0.6
# 75%      0.918367    0.0625       0.9375         0.6
# max      0.937500    0.0625       0.9375         0.6
# DecisionTreeClassifier-GridSearchCV model runs:
# ====================================================================================================
#       true_positive  true_negative  false_negative  false_postive  accuracy  \
# RUN#
# 0                67             47               5              1  0.950000
# 1                70             47               2              1  0.975000
# 2                72             44               0              4  0.966667
# 3                70             44               2              4  0.950000
# 4                72             44               0              4  0.966667
# ...             ...            ...             ...            ...       ...
# 95               68             48               4              0  0.966667
# 96               68             47               4              1  0.958333
# 97               71             41               1              7  0.933333
# 98               71             42               1              6  0.941667
# 99               65             44               7              4  0.908333
#
#       precision    recall  f1_score  misclassification       npv       fpr  \
# RUN#
# 0      0.985294  0.930556  0.957143           0.050000  0.903846  0.020833
# 1      0.985915  0.972222  0.979021           0.025000  0.959184  0.020833
# 2      0.947368  1.000000  0.972973           0.033333  1.000000  0.083333
# 3      0.945946  0.972222  0.958904           0.050000  0.956522  0.083333
# 4      0.947368  1.000000  0.972973           0.033333  1.000000  0.083333
# ...         ...       ...       ...                ...       ...       ...
# 95     1.000000  0.944444  0.971429           0.033333  0.923077  0.000000
# 96     0.985507  0.944444  0.964539           0.041667  0.921569  0.020833
# 97     0.910256  0.986111  0.946667           0.066667  0.976190  0.145833
# 98     0.922078  0.986111  0.953020           0.058333  0.976744  0.125000
# 99     0.942029  0.902778  0.921986           0.091667  0.862745  0.083333
#
#       specificity  prevalence imputation
# RUN#
# 0        0.979167         0.6        knn
# 1        0.979167         0.6        knn
# 2        0.916667         0.6        knn
# 3        0.916667         0.6        knn
# 4        0.916667         0.6        knn
# ...           ...         ...        ...
# 95       1.000000         0.6        knn
# 96       0.979167         0.6        knn
# 97       0.854167         0.6        knn
# 98       0.875000         0.6        knn
# 99       0.916667         0.6        knn
#
# [100 rows x 14 columns]
# DecisionTreeClassifier-GridSearchCV model run statistics:
# ====================================================================================================
#        true_positive  true_negative  false_negative  false_postive  \
# count     100.000000     100.000000      100.000000     100.000000
# mean       69.100000      44.410000        2.900000       3.590000
# std         2.480225       2.318546        2.480225       2.318546
# min        60.000000      38.000000        0.000000       0.000000
# 25%        68.000000      43.000000        1.000000       2.000000
# 50%        69.000000      44.000000        3.000000       4.000000
# 75%        71.000000      46.000000        4.000000       5.000000
# max        72.000000      48.000000       12.000000      10.000000
#
#          accuracy   precision      recall    f1_score  misclassification  \
# count  100.000000  100.000000  100.000000  100.000000         100.000000
# mean     0.945917    0.951852    0.959722    0.955066           0.054083
# std      0.022768    0.029352    0.034448    0.019187           0.022768
# min      0.883333    0.871795    0.833333    0.902778           0.008333
# 25%      0.925000    0.933766    0.944444    0.940982           0.041667
# 50%      0.950000    0.947368    0.958333    0.957746           0.050000
# 75%      0.958333    0.972222    0.986111    0.966443           0.075000
# max      0.991667    1.000000    1.000000    0.993103           0.116667
#
#               npv         fpr  specificity  prevalence
# count  100.000000  100.000000   100.000000       100.0
# mean     0.941763    0.074792     0.925208         0.6
# std      0.045962    0.048303     0.048303         0.0
# min      0.800000    0.000000     0.791667         0.6
# 25%      0.919592    0.041667     0.895833         0.6
# 50%      0.941176    0.083333     0.916667         0.6
# 75%      0.977778    0.104167     0.958333         0.6
# max      1.000000    0.208333     1.000000         0.6
# RandomForestClassifier model runs:
# ====================================================================================================
#       true_positive  true_negative  false_negative  false_postive  accuracy  \
# RUN#
# 0                72             44               0              4  0.966667
# 1                72             47               0              1  0.991667
# 2                72             47               0              1  0.991667
# 3                72             44               0              4  0.966667
# 4                72             48               0              0  1.000000
# ...             ...            ...             ...            ...       ...
# 95               72             48               0              0  1.000000
# 96               72             48               0              0  1.000000
# 97               72             45               0              3  0.975000
# 98               72             46               0              2  0.983333
# 99               72             48               0              0  1.000000
#
#       precision  recall  f1_score  misclassification  npv       fpr  \
# RUN#
# 0      0.947368     1.0  0.972973           0.033333  1.0  0.083333
# 1      0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 2      0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 3      0.947368     1.0  0.972973           0.033333  1.0  0.083333
# 4      1.000000     1.0  1.000000           0.000000  1.0  0.000000
# ...         ...     ...       ...                ...  ...       ...
# 95     1.000000     1.0  1.000000           0.000000  1.0  0.000000
# 96     1.000000     1.0  1.000000           0.000000  1.0  0.000000
# 97     0.960000     1.0  0.979592           0.025000  1.0  0.062500
# 98     0.972973     1.0  0.986301           0.016667  1.0  0.041667
# 99     1.000000     1.0  1.000000           0.000000  1.0  0.000000
#
#       specificity  prevalence imputation
# RUN#
# 0        0.916667         0.6        knn
# 1        0.979167         0.6        knn
# 2        0.979167         0.6        knn
# 3        0.916667         0.6        knn
# 4        1.000000         0.6        knn
# ...           ...         ...        ...
# 95       1.000000         0.6        knn
# 96       1.000000         0.6        knn
# 97       0.937500         0.6        knn
# 98       0.958333         0.6        knn
# 99       1.000000         0.6        knn
#
# [100 rows x 14 columns]
# RandomForestClassifier model run statistics:
# ====================================================================================================
#        true_positive  true_negative  false_negative  false_postive  \
# count     100.000000     100.000000      100.000000     100.000000
# mean       71.940000      46.000000        0.060000       2.000000
# std         0.238683       1.524215        0.238683       1.524215
# min        71.000000      44.000000        0.000000       0.000000
# 25%        72.000000      44.750000        0.000000       0.750000
# 50%        72.000000      46.000000        0.000000       2.000000
# 75%        72.000000      47.250000        0.000000       3.250000
# max        72.000000      48.000000        1.000000       4.000000
#
#          accuracy   precision      recall    f1_score  misclassification  \
# count  100.000000  100.000000  100.000000  100.000000         100.000000
# mean     0.982833    0.973373    0.999167    0.985988           0.017167
# std      0.012469    0.020058    0.003315    0.010108           0.012469
# min      0.966667    0.947368    0.986111    0.972603           0.000000
# 25%      0.966667    0.956437    1.000000    0.972973           0.008333
# 50%      0.983333    0.972973    1.000000    0.986301           0.016667
# 75%      0.991667    0.989726    1.000000    0.993103           0.033333
# max      1.000000    1.000000    1.000000    1.000000           0.033333
#
#               npv         fpr  specificity  prevalence
# count  100.000000  100.000000   100.000000       100.0
# mean     0.998754    0.041667     0.958333         0.6
# std      0.004959    0.031754     0.031754         0.0
# min      0.978261    0.000000     0.916667         0.6
# 25%      1.000000    0.015625     0.932292         0.6
# 50%      1.000000    0.041667     0.958333         0.6
# 75%      1.000000    0.067708     0.984375         0.6
# max      1.000000    0.083333     1.000000         0.6
# XGBClassifier model runs:
# ====================================================================================================
#       true_positive  true_negative  false_negative  false_postive  accuracy  \
# RUN#
# 0                72             47               0              1  0.991667
# 1                72             47               0              1  0.991667
# 2                72             47               0              1  0.991667
# 3                72             47               0              1  0.991667
# 4                72             47               0              1  0.991667
# ...             ...            ...             ...            ...       ...
# 95               72             47               0              1  0.991667
# 96               72             47               0              1  0.991667
# 97               72             47               0              1  0.991667
# 98               72             47               0              1  0.991667
# 99               72             47               0              1  0.991667
#
#       precision  recall  f1_score  misclassification  npv       fpr  \
# RUN#
# 0      0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 1      0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 2      0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 3      0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 4      0.986301     1.0  0.993103           0.008333  1.0  0.020833
# ...         ...     ...       ...                ...  ...       ...
# 95     0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 96     0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 97     0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 98     0.986301     1.0  0.993103           0.008333  1.0  0.020833
# 99     0.986301     1.0  0.993103           0.008333  1.0  0.020833
#
#       specificity  prevalence imputation
# RUN#
# 0        0.979167         0.6        knn
# 1        0.979167         0.6        knn
# 2        0.979167         0.6        knn
# 3        0.979167         0.6        knn
# 4        0.979167         0.6        knn
# ...           ...         ...        ...
# 95       0.979167         0.6        knn
# 96       0.979167         0.6        knn
# 97       0.979167         0.6        knn
# 98       0.979167         0.6        knn
# 99       0.979167         0.6        knn
#
# [100 rows x 14 columns]
# XGBClassifier model run statistics:
# ====================================================================================================
#        true_positive  true_negative  false_negative  false_postive  \
# count          100.0     100.000000           100.0     100.000000
# mean            72.0      47.000000             0.0       1.000000
# std              0.0       0.142134             0.0       0.142134
# min             72.0      46.000000             0.0       0.000000
# 25%             72.0      47.000000             0.0       1.000000
# 50%             72.0      47.000000             0.0       1.000000
# 75%             72.0      47.000000             0.0       1.000000
# max             72.0      48.000000             0.0       2.000000
#
#          accuracy   precision  recall    f1_score  misclassification    npv  \
# count  100.000000  100.000000   100.0  100.000000         100.000000  100.0
# mean     0.991667    0.986305     1.0    0.993104           0.008333    1.0
# std      0.001184    0.001921     0.0    0.000974           0.001184    0.0
# min      0.983333    0.972973     1.0    0.986301           0.000000    1.0
# 25%      0.991667    0.986301     1.0    0.993103           0.008333    1.0
# 50%      0.991667    0.986301     1.0    0.993103           0.008333    1.0
# 75%      0.991667    0.986301     1.0    0.993103           0.008333    1.0
# max      1.000000    1.000000     1.0    1.000000           0.016667    1.0
#
#               fpr  specificity  prevalence
# count  100.000000   100.000000       100.0
# mean     0.020833     0.979167         0.6
# std      0.002961     0.002961         0.0
# min      0.000000     0.958333         0.6
# 25%      0.020833     0.979167         0.6
# 50%      0.020833     0.979167         0.6
# 75%      0.020833     0.979167         0.6
# max      0.041667     1.000000         0.6
# LogisticRegression model runs:
# ====================================================================================================
#       true_positive  true_negative  false_negative  false_postive  accuracy  \
# RUN#
# 0                70             48               2              0  0.983333
# 1                69             48               3              0  0.975000
# 2                69             48               3              0  0.975000
# 3                70             48               2              0  0.983333
# 4                70             48               2              0  0.983333
# ...             ...            ...             ...            ...       ...
# 95               69             48               3              0  0.975000
# 96               69             48               3              0  0.975000
# 97               69             48               3              0  0.975000
# 98               69             48               3              0  0.975000
# 99               71             48               1              0  0.991667
#
#       precision    recall  f1_score  misclassification       npv  fpr  \
# RUN#
# 0           1.0  0.972222  0.985915           0.016667  0.960000  0.0
# 1           1.0  0.958333  0.978723           0.025000  0.941176  0.0
# 2           1.0  0.958333  0.978723           0.025000  0.941176  0.0
# 3           1.0  0.972222  0.985915           0.016667  0.960000  0.0
# 4           1.0  0.972222  0.985915           0.016667  0.960000  0.0
# ...         ...       ...       ...                ...       ...  ...
# 95          1.0  0.958333  0.978723           0.025000  0.941176  0.0
# 96          1.0  0.958333  0.978723           0.025000  0.941176  0.0
# 97          1.0  0.958333  0.978723           0.025000  0.941176  0.0
# 98          1.0  0.958333  0.978723           0.025000  0.941176  0.0
# 99          1.0  0.986111  0.993007           0.008333  0.979592  0.0
#
#       specificity  prevalence imputation
# RUN#
# 0             1.0         0.6        knn
# 1             1.0         0.6        knn
# 2             1.0         0.6        knn
# 3             1.0         0.6        knn
# 4             1.0         0.6        knn
# ...           ...         ...        ...
# 95            1.0         0.6        knn
# 96            1.0         0.6        knn
# 97            1.0         0.6        knn
# 98            1.0         0.6        knn
# 99            1.0         0.6        knn
#
# [100 rows x 14 columns]
# LogisticRegression model run statistics:
# ====================================================================================================
#        true_positive  true_negative  false_negative  false_postive  \
# count     100.000000          100.0      100.000000          100.0
# mean       69.400000           48.0        2.600000            0.0
# std         0.550482            0.0        0.550482            0.0
# min        68.000000           48.0        1.000000            0.0
# 25%        69.000000           48.0        2.000000            0.0
# 50%        69.000000           48.0        3.000000            0.0
# 75%        70.000000           48.0        3.000000            0.0
# max        71.000000           48.0        4.000000            0.0
#
#          accuracy  precision      recall    f1_score  misclassification  \
# count  100.000000      100.0  100.000000  100.000000         100.000000
# mean     0.978333        1.0    0.963889    0.981597           0.021667
# std      0.004587        0.0    0.007646    0.003956           0.004587
# min      0.966667        1.0    0.944444    0.971429           0.008333
# 25%      0.975000        1.0    0.958333    0.978723           0.016667
# 50%      0.975000        1.0    0.958333    0.978723           0.025000
# 75%      0.983333        1.0    0.972222    0.985915           0.025000
# max      0.991667        1.0    0.986111    0.993007           0.033333
#
#               npv    fpr  specificity  prevalence
# count  100.000000  100.0        100.0       100.0
# mean     0.948728    0.0          1.0         0.6
# std      0.010389    0.0          0.0         0.0
# min      0.923077    0.0          1.0         0.6
# 25%      0.941176    0.0          1.0         0.6
# 50%      0.941176    0.0          1.0         0.6
# 75%      0.960000    0.0          1.0         0.6
# max      0.979592    0.0          1.0         0.6
